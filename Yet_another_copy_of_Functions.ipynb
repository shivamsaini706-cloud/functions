# %% [markdown]
# Functions
#
# 1. What is difference between a function and a method in python?
#
# <- . Function is a block of reusable code that performs a specific task and is independent whereas method is associated with a object or class.
#
#    . Function is defined using def or lambda while method is defined inside a class.
#
#    . Function can be called independently whereas method is called on an object.
#
# 2. Explain the concept of function argument and parameters in python?
#
# <- Parameters are the placeholders or variables defined in a function .
#
#    Arguments are the actual values passed when calling the function.
#
#    Parameters can be considered as a empty container in which agruments as values are put inside a container.
#
#   -  Types of function arguments in python-
#
#    . positional arguments
#
#    . keyword arguments
#
#    . default arguments
#
#  -  parameter order in python
#
#   . normal parameters
#
#   . *args
#
#   . default parameters
#
#   . **kwargs
#
# 3. What are the different ways to define and call a function in python?
#
# <- . normal function(using def)
#
#    ex.-
#
#    def greet(name):
#
#    return f"hello, {name}!"
#
#    print(greet("shivam"))
#
#
#    . function with default parameters
#
#    ex.-
#
#    def greet(name = "guest")
#
#    return f"hello , {name}!"
#
#    print (greet())
#
#    print(greet("shivam"))
#
#    . function with keyword arguments
#
#    . variable length arguments
#
#    . nested functions
#
# 4. What is purpose of 'return' statement in a python funcion?
#
# <- . Sends a value back to the caller
#
#    . Ends the function immediately
#
#    . return multiple values
#
#    . return none by default-if you dont use return,function automatically returns none.
#
# 5. What are iterators in python and how do they differ from iterables?
#
# <- An iterator is an object that represent a stream of data fetching one element at a time.it has 2 main methods-
#
# _iter_() - return the iterator object itself
#
# _next_() - return the next element
#
# difference-
#
# . Iterator is a object that produces data whereas iterable is a object that can return an iterable
#
# 6. Explain concept of generators in python and how they are defined?
#
# <- A generator is a functon that produces item one at a time instead of returning them all at once like a list.
#
#  They are very memory efficient for large datasheets.
#
#  generators are defined as-
#
#  . generator function - uses keyword yield instead of return
#
#  . generator expression - similar to list but uses () instead of []
#
# 7. What are the advantages of using generator over regular function?
#
# <- . Generatrs have higher memory efficiency as compared to functions
#
#    . Infinite sequence is possible in generators whereas functions cannot produce infinite items.
#
#    . startup time is faster in generators
#
#    . Generators have a cleaner state managment as compared to regular function
#
#    . Generator can be chained together for data pipelines.
#
# 8. What is lambda function in python and when is it typically used?
#
# <- A lambda function is a nameless function in python defined using the keyword lambda instead of def.
#
#   It can have any number of arguments but only one expression.
#
#   It is typically used when-
#
#   . short function is needed for a short time.
#
#   . used as arguments to higher order functions.
#
# 9. Explain the purpose and usage of 'map()' function in pythn?
#
# <- purpose of map() -
#
#    . map() function applies a function to each item of an iterable and return as map object
#
#    . mainly used when element by element data transformation is required.
#
#    usage-
#
#    . using with lambda function-
#
#    nums = [1,2,3,4]
#
#    squares = list(map(lambda x : x**2, nums))
#
#    print (squares)
#
#    . using with multile iterables-
#
#    a = [1,2,3]
#
#    b = [4,5,6]
#
#    result = map(lambda x,y : x+y,a,b)
#
#    print(list(result))
#
# 10. What is difference between 'map()','reduce()' and 'filter()' functions in python?
#
# <- Purpose - .map() applies a given function to each element of an iterable and
#
#               return a new iterable.
#
#              . filter() applies a function that returns true/false to each
#
#               element and keeps only those that return true.
#
#               . reduce() applies the function cummulative to the elements of an
#
#                iterable reducing it to a single value.
#
#  when to use - . map() is used when you want to transform each item.
#
#                . filter() is used to filter out certain elements
#
#                . reduce() is used if you want to aggregate or combine all
#
#                values.
#
# 11. Using pen and paper write the inernal mechanism for sum operations using
#
# reduce function on this given list [47,11,42,13]?
#
# <-

# %%
practical

1. Write a python function that takes a list of numbers as input and return sum of all even numbers in he list?

def sum_of_even(numbers):

  total = 0

  for num in numbers:

    if num % 2 == 0:

      total + = num

      return total

      num = [1,2,3,4,5,6]

      print(sum_of_even(nums))

      output :

      12

 2. create a python function that accepts a string and return the reverse of that string?

 def reverse_string(s):

  return s[::-1]

  text = "hello"

  print (reverse_string(text))

  output :

  olleh

3. Implement a python function that takes a list of integers  and return a new list containing squares of each number?

def square_list(numbers):

  return[num** 2 for num in numbers]

  nums = [1,2,3,4,5]

  print(square_list(num))

  output:

  [1,4,9,16,25]

4. Write a python function checks if a given number is prime or not from 1 to 200?

def is_prime(n):

  if n<2:

    return false

    for i in range (2,int(n**0,5) +1):

      if n % i == 0:

        return false

        return true

        for num in range(1,201):

          print(num,"is prime" if is_prime(num) else "is not prime")

          output:

          1 is not prime

          2 is prime

          3 is prime

          4 is not prime

          ...

          200 is not prime

5. create an iterator class in python that genertes the fibonnaci sequence upt a specific umber of terms?

6. write a generator function in pythn that yields the power of 2 upto a given exponent?

def power_of_two(max_exponent):

  for i in range(max_exponent + 1):

    yield 2 ** i

    for value in power_of_two(5):

     print(value, end = " ")

     output:
     11 2 4 8 32

7. Implement a generator function that reads a file line by line and yields each line as a string?

def read_file_lines(file_path):

  """

  """

  with open(file_path, 'r') as file:

    for line in file:

      yield line.rstrip('\n')

      file_path = 'example.txt'

      for line in read_file_lines(file_path):

        print(line)

8. use a lambda function in python to sort a list of tuples based on 2nd element of each tuple?

tuples_list[(1,6),(2,3),(4,1),(3,1)]

sorted_list = sorted(tuples_list,
                     key = lambda x:x[1])

print(sorted_list)

output:

[(4,1),(2,3),(3,4),(1,6)]

9. write a python program that uses 'map()' to convert a list of temprature from celsius to farenhie?

def c_to_f(celsius):

  return(celsius * 9/5) + 32

  celsius_list = [0,1,2,3,4]

  fahrenheit_list = list(map(c_to_f,celsius_list))

  print("celsius list:", celsius_list)

  print("fahrenheit list:", fahrenheit_list)

  output:

  celsius list: [0,1,2,3,4]
  fahrenheit list: [32,5,6.8,8.6,10.4]

10. create a python program that uses 'filter()' to remove all the vowels from a given string?

def not_vowel(char):

  vowels = "aeiouAEIOU"

  return char not in vowels

  text = "hello world,whats upp"

  result = "".join(filter(not_vowel,text))

  print("original string:",text)

  print("string without vowels:",result)

  output:

  original string: hello world,whats upp

  string without vowels: hll wrld,whts pp
# Out:
#   File "<tokenize>", line 25
#     2. create a python function that accepts a string and return the reverse of that string?
#     ^
# IndentationError: unindent does not match any outer indentation level
